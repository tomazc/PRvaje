# %% [markdown]
# # Podatkovno rudarjenje - zbirka vaj in nalog
#
# Martin Stražar, Rok Gomišček, Tomaž Curk
# 2019, Univerza v Ljubljani, Fakulteta za računalništvo in informatiko

# %% [markdown]
# # Data Mining Exercises
#
# Rok Gomišček, Martin Stražar, Tomaž Curk
# 2019, University of Ljubljana, Faculty of Computer and Information Science

# %% [markdown]
# ## Delovno okolje
#
# * [Namestitev](001-namestitev.ipynb)
# * [Git in github](002-git_in_github.ipynb)
#
#
# ## 1. Priprava podatkov
#
# * [Knjižnica `numpy`](101-1_podatki_numpy.ipynb#Knjižnica-numpy)
# * [Primer: statistika temperatur na severu](101-2_podatki_temperatura.ipynb)
#
#
# ## 2. Prikazovanje podatkov
#
# * [Knjižnica `matplotlib`](102-1_prikaz_matplotlib.ipynb#Knjižnica-matplotlib)
# * [Primer: zimske olimpijske igre, Soči 2014](102-2_prikaz_olimpijske.ipynb)
#
#
# ## 3. Porazdelitve in osamelci
#
# * [Porazdelitve in osamelci](103-1_porazdelitve.ipynb)
# * [Primer: iskanje neslanih šal](103-2_osamelci.ipynb)
#
#
# ## 4. [Odkrivanje skupin](104-1_grucenje_voditelji.ipynb)
#
# * [Metoda voditeljev](104-1_grucenje_voditelji.ipynb#Metoda-voditeljev)
# * [Hierarhično gručenje](104-2_grucenje_hierarhicno.ipynb)
# * [Primer: genomski podatki](104-3_grucenje_genomski.ipynb)
#
#
# ## 5. [Nadzorovano učenje](105-1_nadzorovano_linreg.ipynb)
#
# * [Linearna regresija](105-1_nadzorovano_linreg.ipynb#Linearna-regresija)
# * [Naivni Bayesov klasifikator](105-2_nadzorovano_naivniBayes.ipynb)
#
#
# ## 6. [Nenegativna matrična faktorizacija in zlivanje podatkov](106-1_NMF.ipynb)
#
#
# ## 7. [Omrežja](107-1_omrezja_networkx.ipynb)
#
# * [Knjižnica `networkx`](107-1_omrezja_networkx.ipynb#Knjižica-networkx)
# * [Primer: omrežje elektronskih sporočil](107-2_omrezja_email.ipynb)
#
#
# ## 8. [Zaporedja](108-1_zaporedja_HMM.ipynb)
# * [Skriti Markovi modeli](108-1_zaporedja_HMM.ipynb#Skriti-Markovi-modeli)
# * [Časovne vrste](108-2_zaporedja_casovne.ipynb)
# * [Napovedovanje trendov](108-3_zaporedja_trendi.ipynb)
#
#
# ## Naloge
#
# * [Priprava in pregled podatkov](301-priprava_pregled.ipynb)
# * [Iskanje strukture v podatkih](302-struktura_podatkov.ipynb)
# * [Napovedovanje vrednosti](303-nadzorovano_ucenje.ipynb)
# * [Uporaba matrične faktorizacije za napovedovanje](304-matricna_faktorizacija.ipynb)
# * [Implementacija priporočilnega sistema](305-aplikacija.ipynb)
#
#
# ## [Literatura](900-lit.ipynb)

# %% [markdown]
# ## Work environment
#
# * [Setup](001-namestitev.ipynb)
# * [Git and github](002-git_in_github.ipynb)
#
# ## 1. Data preparation
#
# * [Library `numpy`](101-1_podatki_numpy.ipynb#Knjižnica-numpy)
# * [Primer: statistika temperatur na severu](101-2_podatki_temperatura.ipynb)
#
#
# ## 2. Plotting data
#
# * [Knjižnica matplotlib](102-1_prikaz_matplotlib.ipynb#Knjižnica-matplotlib)
# * [Example: Winter Olympics, Sochi 2014](102-2_prikaz_olimpijske.ipynb)
#
#
# ## 3. Distributions and outliers
#
# * [Distributions and outliers](103-1_porazdelitve.ipynb)
# * [Example: finding unfunny jokes](103-2_osamelci.ipynb)
#
#
# ## 4. [Clustering](104-1_grucenje_voditelji.ipynb)
#
# * [K-means clustering](104-1_grucenje_voditelji.ipynb#Metoda-voditeljev)
# * [Hierarchical clustering](104-2_grucenje_hierarhicno.ipynb)
# * [Example: genomic data](104-3_grucenje_genomski.ipynb)
#
#
# ## 5. [Supervised learning](105-1_nadzorovano_linreg.ipynb)
#
# * [Linear regression](105-1_nadzorovano_linreg.ipynb#Linearna-regresija)
# * [Naive Bayes classifier](105-2_nadzorovano_naivniBayes.ipynb)
#
#
# ## 6. [Non-negative matrix factorization and recommender systems](106-1_NMF.ipynb)
#
#
# ## 7. [Networks](107-1_omrezja_networkx.ipynb)
#
# * [Library `networkx`](107-1_omrezja_networkx.ipynb#Knjižica-networkx)
# * [Example: emails network](107-2_omrezja_email.ipynb)
#
#
# ## 8. [Data series](108-1_zaporedja_HMM.ipynb)
# * [Hidden Markov Models](108-1_zaporedja_HMM.ipynb#Skriti-Markovi-modeli)
# * [Time series](108-2_zaporedja_casovne.ipynb)
# * [Predicting trends](108-3_zaporedja_trendi.ipynb)
#
#
# ## Naloge
#
# * [Data preparation, basic statistics and visualization](301-priprava_pregled.ipynb)
# * [Search for structure in data](302-struktura_podatkov.ipynb)
# * [Predicting values](303-nadzorovano_ucenje.ipynb)
# * [Predicting by matrix factorization](304-matricna_faktorizacija.ipynb)
# * [Implementation of a recommendation system](305-aplikacija.ipynb)
#
#
# ## [Literatura](900-lit.ipynb)
